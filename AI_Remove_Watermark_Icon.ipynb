# %%
print('Tạo Thư Mục Cần Thiết')
# %mkdir -p /content/app
# %cd /content/app
print('Tải Ứng Dụng')
# !wget -q --show-progress "https://source.nguoiyeucu.nyc/download/ai_remove_watermark_google_colab.zip" -O app.zip
print('Giải nén ứng dụng')
# !unzip -q -o app.zip && rm app.zip

# %%
#mount thư mục kết quả vào google drive cá nhân tránh mất dữ liệu cần thiết
# !mkdir /content/app/content/app/image_results
print('Đang kết nối google drive')
from google.colab import drive
drive.mount('/content/app/content/app/image_results')

# %%
#Chạy ứng dụngprint('Cài Đặt Ứng Dụng')
# %cd /content/app/content/app
# !chmod +x app
# !./app
